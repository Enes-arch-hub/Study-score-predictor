# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", plt.matplotlib.__version__)
print("Seaborn:", sns.__version__)
print("Scikit-learn ready ✅")
# Out:
# NumPy: 2.4.2
# Pandas: 3.0.0
# Matplotlib: 3.10.8
# Seaborn: 0.13.2
# Scikit-learn ready ✅

# %%
import pandas as pd

# Create a simple dataset
data = {
    "Hours_Studied": [1, 2, 3, 4, 5, 6, 7, 8],
    "Score": [35, 40, 50, 55, 60, 70, 75, 85]
}

df = pd.DataFrame(data)

# View the data
df
# Out:
#    Hours_Studied  Score
# 0              1     35
# 1              2     40
# 2              3     50
# 3              4     55
# 4              5     60
# 5              6     70
# 6              7     75
# 7              8     85

# %%
df.head()
df.describe()
# Out:
#        Hours_Studied      Score
# count        8.00000   8.000000
# mean         4.50000  58.750000
# std          2.44949  17.268882
# min          1.00000  35.000000
# 25%          2.75000  47.500000
# 50%          4.50000  57.500000
# 75%          6.25000  71.250000
# max          8.00000  85.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

plt.figure()
sns.scatterplot(x="Hours_Studied", y="Score", data=df)

plt.title("Study Hours vs Exam Score")
plt.xlabel("Hours Studied")
plt.ylabel("Score")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Features (X) and target (y)
X = df[["Hours_Studied"]]
y = df["Score"]

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# Train model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predicted = model.predict([[6]])
print("Predicted score for 6 hours of study:", predicted[0])
# Out:
# Predicted score for 6 hours of study: 69.19999999999999
# C:\Users\Enes\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("Slope (learning rate):", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope (learning rate): 6.899999999999999
# Intercept: 27.800000000000004

# %%
from sklearn.metrics import mean_squared_error

y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)

print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 1.6000000000000114
